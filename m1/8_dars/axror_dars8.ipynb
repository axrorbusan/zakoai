# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
fb = pd.read_csv('files/fb_stock_prices_2018.csv', index_col='date', parse_dates=True)
plt.plot(fb.index, fb.open)

# %%
fb
# Out:
#               open    high       low   close    volume
# date
# 2018-01-02  177.68  181.58  177.5500  181.42  18151903
# 2018-01-03  181.88  184.78  181.3300  184.67  16886563
# 2018-01-04  184.90  186.21  184.0996  184.33  13880896
# 2018-01-05  185.59  186.90  184.9300  186.85  13574535
# 2018-01-08  187.20  188.90  186.3300  188.28  17994726
# ...            ...     ...       ...     ...       ...
# 2018-12-24  123.10  129.74  123.0200  124.06  22066002
# 2018-12-26  126.00  134.24  125.8900  134.18  39723370
# 2018-12-27  132.44  134.99  129.6700  134.52  31202509
# 2018-12-28  135.34  135.92  132.2000  133.20  22627569
# 2018-12-31  134.45  134.64  129.9500  131.09  24625308
#
# [251 rows x 5 columns]

# %%
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2018-01-02 to 2018-12-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    251 non-null    float64
#  1   high    251 non-null    float64
#  2   low     251 non-null    float64
#  3   close   251 non-null    float64
#  4   volume  251 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 11.8 KB

# %%
fb.isnull().sum()
# Out:
# open      0
# high      0
# low       0
# close     0
# volume    0
# dtype: int64

# %%
fb.value_counts()
# Out:
# open     high      low     close   volume
# 123.100  129.7400  123.02  124.06  22066002     1
# 183.010  188.1800  181.84  187.12  20858556     1
# 180.500  180.5000  176.84  179.96  20922120     1
# 180.710  181.9900  178.62  181.11  19101995     1
# 180.800  185.3900  180.41  185.37  21059464     1
#                                                ..
# 164.580  165.7036  163.77  164.52  19990561     1
# 164.800  173.4000  163.30  169.39  106598834    1
# 165.360  168.6500  163.25  166.32  56144633     1
# 165.430  166.1000  158.19  159.69  35079926     1
# 215.715  218.6200  214.27  217.50  64592585     1
# Name: count, Length: 251, dtype: int64

# %%
plt.plot('high', 'low', 'xb', data=fb.head(20))

# %%
quakes = pd.read_csv('files/earthquakes.csv')
plt.hist(quakes[quakes['mag'] >= 5].mag)
# Out:
# (array([81., 26., 21., 11.,  7.,  0.,  3.,  0.,  1.,  1.]),
#  array([5.  , 5.25, 5.5 , 5.75, 6.  , 6.25, 6.5 , 6.75, 7.  , 7.25, 7.5 ]),
#  <BarContainer object of 10 artists>)

# %%
# Bin hajmi muhim
x = quakes.query('magType == "ml"').mag
fig, axes = plt.subplots(1, 2, figsize = (10, 3) )
for ax, bins in zip(axes, [7, 35 ]):
    ax.hist(x, bins=bins)
    ax.set_title(f'bins param: {bins}')

# %%
# Bin hajmi muhim
x = quakes.query('magType == "ml"').mag
fig, axes = plt.subplots(1, 2, figsize = (10, 3) )
for ax, bins in zip(axes, [7, len(x) ]):
    ax.hist(x, bins=bins)
    ax.set_title(f'bins param: {bins}')

# %%
fig = plt.figure()

# %%
fig, axes = plt.subplots(2,3)

# %%
fig = plt.figure(figsize=(4,4))

# %%
outside = fig.add_axes([0,0,1,1])

# %%
inside=fig.add_axes([0.5,0.5,0.1,0.1])

# %%
fig = plt.figure(figsize=(4,4))     
outside = fig.add_axes([0,0,1,1])
inside=fig.add_axes([0.5,0.5,0.1,0.1])

# %%
fig = plt.figure(figsize=(8, 8))
gs = fig.add_gridspec(3, 3)
top_left = fig.add_subplot(gs[0, 0])
mid_left = fig.add_subplot(gs[1, 0])
top_right = fig.add_subplot(gs[:2, 1:])
bottom = fig.add_subplot(gs[2, :])

# %%
fig.savefig('files/empty.png')

# %%
plt.close('all')

# %%
fig

# %%
fig = plt.figure(figsize=(10,5))

# %%
fig,axes=plt.subplots(1,2,figsize=(10,10))

# %%
import random
import matplotlib as mpl

# %%
rcparams_list = list(mpl.rcParams.keys())
rcparams_list
# Out:
# ['_internal.classic_mode',
#  'agg.path.chunksize',
#  'animation.bitrate',
#  'animation.codec',
#  'animation.convert_args',
#  'animation.convert_path',
#  'animation.embed_limit',
#  'animation.ffmpeg_args',
#  'animation.ffmpeg_path',
#  'animation.frame_format',
#  'animation.html',
#  'animation.writer',
#  'axes.autolimit_mode',
#  'axes.axisbelow',
#  'axes.edgecolor',
#  'axes.facecolor',
#  'axes.formatter.limits',
#  'axes.formatter.min_exponent',
#  'axes.formatter.offset_threshold',
#  'axes.formatter.use_locale',
#  'axes.formatter.use_mathtext',
#  'axes.formatter.useoffset',
#  'axes.grid',
#  'axes.grid.axis',
#  'axes.grid.which',
#  'axes.labelcolor',
#  'axes.labelpad',
#  'axes.labelsize',
#  'axes.labelweight',
#  'axes.linewidth',
#  'axes.prop_cycle',
#  'axes.spines.bottom',
#  'axes.spines.left',
#  'axes.spines.right',
#  'axes.spines.top',
#  'axes.titlecolor',
#  'axes.titlelocation',
#  'axes.titlepad',
#  'axes.titlesize',
#  'axes.titleweight',
# ...

# %%
len(rcparams_list)
# Out:
# 322

# %%
sorted(rcparams_list[:20])
# Out:
# ['_internal.classic_mode',
#  'agg.path.chunksize',
#  'animation.bitrate',
#  'animation.codec',
#  'animation.convert_args',
#  'animation.convert_path',
#  'animation.embed_limit',
#  'animation.ffmpeg_args',
#  'animation.ffmpeg_path',
#  'animation.frame_format',
#  'animation.html',
#  'animation.writer',
#  'axes.autolimit_mode',
#  'axes.axisbelow',
#  'axes.edgecolor',
#  'axes.facecolor',
#  'axes.formatter.limits',
#  'axes.formatter.min_exponent',
#  'axes.formatter.offset_threshold',
#  'axes.formatter.use_locale']

# %%
mpl.rcParams['figure.figsize']
# Out:
# [6.4, 4.8]

# %%
mpl.rcParams['figure.figsize']=(100,50)
mpl.rcParams['figure.figsize']
# Out:
# [100.0, 50.0]

# %%
mpl.rcdefaults()
mpl.rcParams['figure.figsize']
# Out:
# [6.4, 4.8]

# %%
plt.rc('figure', figsize=(20,20))
plt.rcdefaults()

# %%
#2-qism

# %%
quakes = pd.read_csv('files/earthquakes.csv')
covid = pd.read_csv('files/covid19_cases.csv').assign(
    date=lambda x: pd.to_datetime(x.dateRep, format = '%d/%m/%Y')
).set_index('date').replace(
    'United_States_of_America', 'USA'
).sort_index() ['2000-01-18':'2020-09-18']

# %%
quakes
# Out:
#        mag magType           time                             place  tsunami  \
# 0     1.35      ml  1539475168010             9km NE of Aguanga, CA        0
# 1     1.29      ml  1539475129610             9km NE of Aguanga, CA        0
# 2     3.42      ml  1539475062610             8km NE of Aguanga, CA        0
# 3     0.44      ml  1539474978070             9km NE of Aguanga, CA        0
# 4     2.16      md  1539474716050             10km NW of Avenal, CA        0
# ...    ...     ...            ...                               ...      ...
# 9327  0.62      md  1537230228060      9km ENE of Mammoth Lakes, CA        0
# 9328  1.00      ml  1537230135130               3km W of Julian, CA        0
# 9329  2.40      md  1537229908180  35km NNE of Hatillo, Puerto Rico        0
# 9330  1.10      ml  1537229545350             9km NE of Aguanga, CA        0
# 9331  0.66      ml  1537228864470             9km NE of Aguanga, CA        0
#
#      parsed_place
# 0      California
# ...

# %%
covid
# Out:
#                dateRep  day  month  year  cases  deaths  \
# date
# 2019-12-31  31/12/2019   31     12  2019      0       0
# 2019-12-31  31/12/2019   31     12  2019      0       0
# 2019-12-31  31/12/2019   31     12  2019      0       0
# 2019-12-31  31/12/2019   31     12  2019      0       0
# 2019-12-31  31/12/2019   31     12  2019      0       0
# ...                ...  ...    ...   ...    ...     ...
# 2020-09-18  18/09/2020   18      9  2020    822       2
# 2020-09-18  18/09/2020   18      9  2020   4326      84
# 2020-09-18  18/09/2020   18      9  2020     90       0
# 2020-09-18  18/09/2020   18      9  2020      0       0
# 2020-09-18  18/09/2020   18      9  2020     34       8
#
#            countriesAndTerritories geoId countryterritoryCode  popData2019  \
# date
# 2019-12-31                 Belgium    BE                  BEL   11455519.0
# 2019-12-31                  Mexico    MX                  MEX  127575529.0
# ...

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 43510 entries, 2019-12-31 to 2020-09-18
# Data columns (total 12 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   dateRep                                                     43510 non-null  object
#  1   day                                                         43510 non-null  int64
#  2   month                                                       43510 non-null  int64
#  3   year                                                        43510 non-null  int64
#  4   cases                                                       43510 non-null  int64
#  5   deaths                                                      43510 non-null  int64
#  6   countriesAndTerritories                                     43510 non-null  object
# ...

# %%
quakes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9332 entries, 0 to 9331
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mag           9331 non-null   float64
#  1   magType       9331 non-null   object
#  2   time          9332 non-null   int64
#  3   place         9332 non-null   object
#  4   tsunami       9332 non-null   int64
#  5   parsed_place  9332 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 437.6+ KB

# %%
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 251 entries, 2018-01-02 to 2018-12-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   open    251 non-null    float64
#  1   high    251 non-null    float64
#  2   low     251 non-null    float64
#  3   close   251 non-null    float64
#  4   volume  251 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 11.8 KB

# %%
fb.plot(
    kind='line',
    y = 'high',
    figsize=(20,5),
    style='-k',
    legend=False,
    title=f'facebook price chart from {fb.index[0]} to {fb.index[len(fb)-1]}'
)
# Out:
# <Axes: title={'center': 'facebook price chart from 2018-01-02 00:00:00 to 2018-12-31 00:00:00'}, xlabel='date'>

# %%
fb.first('2W')
# Out:
# /var/folders/2s/kw_rwvhn10q4r6bv09y0my5r0000gn/T/ipykernel_731/2151316161.py:1: FutureWarning: first is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   fb.first('2W')
#               open    high       low   close    volume
# date
# 2018-01-02  177.68  181.58  177.5500  181.42  18151903
# 2018-01-03  181.88  184.78  181.3300  184.67  16886563
# 2018-01-04  184.90  186.21  184.0996  184.33  13880896
# 2018-01-05  185.59  186.90  184.9300  186.85  13574535
# 2018-01-08  187.20  188.90  186.3300  188.28  17994726
# 2018-01-09  188.70  188.80  187.1000  187.87  12393057
# 2018-01-10  186.94  187.89  185.6300  187.84  10529894
# 2018-01-11  188.40  188.40  187.3800  187.77   9588587
# 2018-01-12  178.06  181.48  177.4000  179.37  77551299

# %%
fb.first('2W').plot(
    y=['open', 'high', 'low', 'close'],
    style=['o-b', '--r', ':k', '.-g'],
    title='first 2 weeks'
)
# Out:
# /var/folders/2s/kw_rwvhn10q4r6bv09y0my5r0000gn/T/ipykernel_731/290155561.py:1: FutureWarning: first is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   fb.first('2W').plot(
# <Axes: title={'center': 'first 2 weeks'}, xlabel='date'>

# %%
fb.first('2W').plot(
    y=['open', 'high', 'low', 'close'],
    style=['o-b', '--r', ':k', '.-g'],
    title='first 2 weeks'
).autoscale()
# Out:
# /var/folders/2s/kw_rwvhn10q4r6bv09y0my5r0000gn/T/ipykernel_731/2077311964.py:1: FutureWarning: first is deprecated and will be removed in a future version. Please create a mask and filter using `.loc` instead
#   fb.first('2W').plot(

# %%
fb.plot(
    kind='line',
    subplots=True,
    layout=(3,2),
    figsize=(15,10),
    title='facebook '
)
# Out:
# array([[<Axes: xlabel='date'>, <Axes: xlabel='date'>],
#        [<Axes: xlabel='date'>, <Axes: xlabel='date'>],
#        [<Axes: xlabel='date'>, <Axes: xlabel='date'>]], dtype=object)

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 43510 entries, 2019-12-31 to 2020-09-18
# Data columns (total 12 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   dateRep                                                     43510 non-null  object
#  1   day                                                         43510 non-null  int64
#  2   month                                                       43510 non-null  int64
#  3   year                                                        43510 non-null  int64
#  4   cases                                                       43510 non-null  int64
#  5   deaths                                                      43510 non-null  int64
#  6   countriesAndTerritories                                     43510 non-null  object
# ...

# %%
covid.head()
# Out:
#                dateRep  day  month  year  cases  deaths  \
# date
# 2019-12-31  31/12/2019   31     12  2019      0       0
# 2019-12-31  31/12/2019   31     12  2019      0       0
# 2019-12-31  31/12/2019   31     12  2019      0       0
# 2019-12-31  31/12/2019   31     12  2019      0       0
# 2019-12-31  31/12/2019   31     12  2019      0       0
#
#            countriesAndTerritories geoId countryterritoryCode  popData2019  \
# date
# 2019-12-31                 Belgium    BE                  BEL   11455519.0
# 2019-12-31                  Mexico    MX                  MEX  127575529.0
# 2019-12-31                 Ecuador    EC                  ECU   17373657.0
# 2019-12-31                  Russia    RU                  RUS  145872260.0
# 2019-12-31             Netherlands    NL                  NLD   17282163.0
#
#            continentExp  \
# date
# 2019-12-31       Europe
# 2019-12-31      America
# 2019-12-31      America
# 2019-12-31       Europe
# 2019-12-31       Europe
# ...

# %%
new_data=covid.pivot_table(
    index=covid.index,
    columns='countriesAndTerritories',
    values='cases'
).rolling(7).mean()

# %%
new_data
# Out:
# countriesAndTerritories  Afghanistan     Albania     Algeria    Andorra  \
# date
# 2019-12-31                       NaN         NaN         NaN        NaN
# 2020-01-01                       NaN         NaN         NaN        NaN
# 2020-01-02                       NaN         NaN         NaN        NaN
# 2020-01-03                       NaN         NaN         NaN        NaN
# 2020-01-04                       NaN         NaN         NaN        NaN
# ...                              ...         ...         ...        ...
# 2020-09-14                 45.428571  156.857143  270.000000  18.428571
# 2020-09-15                 45.857143  159.142857  263.285714  25.285714
# 2020-09-16                 47.857143  159.857143  256.571429  25.285714
# 2020-09-17                 46.857143  158.857143  250.000000  19.571429
# 2020-09-18                 42.857143  155.428571  243.714286  26.000000
#
# countriesAndTerritories     Angola  Anguilla  Antigua_and_Barbuda  \
# date
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 263 entries, 2019-12-31 to 2020-09-18
# Columns: 210 entries, Afghanistan to Zimbabwe
# dtypes: float64(210)
# memory usage: 433.5 KB

# %%
fig,axes=plt.subplots(1,3, figsize=(15,5))
new_data[['China']].plot(ax=axes[0],style='-.c')
new_data[['Italy', 'France']].plot(ax=axes[1],style=['--r','--k'],
                                   title='7day average covid19 cases')
new_data[['Brazil']].plot(ax=axes[2],style=':')
# Out:
# <Axes: xlabel='date'>

# %%
# Maydon Grafigi
plot_cols = ['Brazil', 'India', 'Italy & Spain', 'USA', 'Other']
grouped = ['Italy', 'Spain']
other_cols = [
    col for col in new_data.columns
    if col not in plot_cols
]

new_data.sort_index(axis=1).assign(
    **{
        'Italy & Spain': lambda x: x[grouped].sum(axis=1),
        'Other': lambda x: x[other_cols].drop(columns=grouped).sum(axis=1)
    }
) [plot_cols].plot(
    kind='area', figsize=(15, 5),
    title='7-day rolling average of new COVID-19 cases\n(source: ECDC)'
)
# Out:
# <Axes: title={'center': '7-day rolling average of new COVID-19 cases\n(source: ECDC)'}, xlabel='date'>

# %%
fb.assign(max_abs_change=fb.high-fb.low
          ).plot(
              kind='scatter', x='volume',y='max_abs_change',
              title='facebook daily high-low volume traded'
          )
# Out:
# <Axes: title={'center': 'facebook daily high-low volume traded'}, xlabel='volume', ylabel='max_abs_change'>

# %%
fb.assign(max_abs_change=fb.high-fb.low
          ).plot(
              kind='scatter', x='volume',y='max_abs_change',
              title='facebook daily high-low volume traded',
              logx=True
          )
# Out:
# <Axes: title={'center': 'facebook daily high-low volume traded'}, xlabel='volume', ylabel='max_abs_change'>

# %%
fb.assign(
    log_volume=np.log(fb.volume),
    max_abs_change=fb.high-fb.low
).plot(
    kind='hexbin',
    x='log_volume',
    y='max_abs_change',
    title='facebook daily high -low vs log volume traded',
    colormap='gray_r',
    gridsize=25,
    sharex=False
)
# Out:
# <Axes: title={'center': 'facebook daily high -low vs log volume traded'}, xlabel='log_volume', ylabel='max_abs_change'>

# %%
fig, ax = plt.subplots(figsize=(20, 10))

# calculate the correlation matrix
fb_corr = fb.assign(
    log_volume=np.log(fb.volume),
    max_abs_change=fb.high - fb.low
).corr()

# create the heatmap and colorbar
im = ax.matshow(fb_corr, cmap='seismic')
im.set_clim(-1, 1)
fig.colorbar(im)

# label the ticks with the column names
label = [col.lower() for col in fb_corr.columns]
ax.set_xticks(ax.get_xticks()[1: -1]) # to handle bug in matplotlib
ax.set_xticklabels(label, rotation=45)
ax.set_yticks(ax.get_yticks()[1: -1]) # to handle bug in matplotlib
ax.set_yticklabels(label)

# include the value of the correlation coefficient in the boxes
for (i, j), coef in np.ndenumerate(fb_corr):
  ax.text(
      i, j, fr'$\rho$ = {coef:.2f}', # raw (r), format (f) string
      ha = 'center', va = 'center',
      color = 'white', fontsize=14
  )

# %%
import seaborn as sns
sns.heatmap(fb.corr(),annot=True)
# Out:
# <Axes: >

# %%
fb_corr.loc['max_abs_change', ['volume', 'log_volume']]
# Out:
# volume        0.642027
# log_volume    0.731542
# Name: max_abs_change, dtype: float64

# %%
fb.volume.plot(
    kind='hist',
    title='histogram'
)
plt.xlabel('volume traded')
# Out:
# Text(0.5, 0, 'volume traded')

# %%
fig, axes=plt.subplots(figsize=(8,5))

for magtype in quakes.magType.unique():
    data = quakes.query(f'magType == "{magtype}"').mag
    if not data.empty:
        data.plot(
            kind='hist',
            ax=axes,
            alpha=0.3,
            label=magtype,
            legend=True,
            title='comparing mag by magtype'
        )

plt.xlabel('magnitude')
# Out:
# Text(0.5, 0, 'magnitude')

# %%
fb.high.plot(
    kind='kde',
    title='KDE of Daily High Price for Facebook Stock'
)
plt.xlabel('Price')
# Out:
# Text(0.5, 0, 'Price')

# %%
ax = fb.high.plot( kind='hist', density=True, alpha=0.5)
fb.high.plot(
    ax=ax, kind='kde', color='blue',
    title='KDE of Daily High Price for Facebook Stock'
)
plt.xlabel('Price ($)')
# Out:
# Text(0.5, 0, 'Price ($)')

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf = ECDF(quakes.query('magType == "ml"').mag)
plt.plot(ecdf.x, ecdf.y)

# axis labels (we will cover in chapter 6)
plt.xlabel('mag') # add x-axis label
plt.ylabel('cumulative probability') # add y-axis label

# add title
plt.title('ECDF of eathquake magnitude with magType ml')
# Out:
# Text(0.5, 1.0, 'ECDF of eathquake magnitude with magType ml')

# %%
from statsmodels.distributions.empirical_distribution import ECDF
ecdf = ECDF(quakes.query('magType == "ml"').mag)
plt.plot(ecdf.x, ecdf.y)

# axis labels (we will cover in chapter 6)
plt.xlabel('mag') # add x-axis label
plt.ylabel('cumulative probability') # add y-axis label

# add reference lines for interpreting the ECDF for mag <=3
plt.plot(
    [3,3], [0, .98], '--k',
    [-1.5, 3], [0.98, 0.98], '--k', alpha=0.4
)
#set axis ranges
plt.ylim(0, None)
plt.xlim(-1.25, None)
# add title
plt.title('P(mag<=3) = 98%')
# Out:
# Text(0.5, 1.0, 'P(mag<=3) = 98%')

# %%
fb.iloc[:, :4].plot(kind='box', title='Facebook OHLC Prices Box Plot')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
fb.iloc[:, :4].plot(kind='box', title='Facebook OHLC Prices Box Plot', notch=True)
plt.ylabel('price ($)')
# Out:
# Text(0, 0.5, 'price ($)')

# %%
quakes[['mag', 'magType']].groupby('magType').boxplot(
    figsize=(15, 8), subplots=False
)
plt.title('Earthquakes Magnitude Box Plots by magType')
plt.ylabel('magnitude')
# Out:
# Text(0, 0.5, 'magnitude')

# %%
quakes.parsed_place.value_counts().iloc[14::-1,].plot(
    kind='barh', figsize=(10, 5),
    title="Top 15 Places for Earthquakes"
          '(September 18, 2018 - October 13, 2018)'
)
plt.xlabel('earthquakes')
# Out:
# Text(0.5, 0, 'earthquakes')
